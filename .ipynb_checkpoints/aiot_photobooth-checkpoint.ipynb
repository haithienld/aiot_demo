# %% [markdown]
# ### Capture New Facial Images
# #### Đây là công cụ chụp tầm 27 ảnh. Mặc định là 27
# #### Khi chụp thì ngồi trước khung ảnh.
# #### Cần đủ 9 hướng mỗi hướng 3 cái:
# 1. Hướng trước mặt
# 2. Hướng mặt ngẩng lên (hơi ngẩng thôi, kiểu như quét khuôn mặt iphone ấy)
# 3. Hướng mặt cúi xuống (hơi cúi thôi, kiểu như quét khuôn mặt iphone ấy)
# 4. Hướng mặt sang trái (TƯƠNG TỰ hơi sang trái - đừng sang quá).
# 5. Hướng mặt sang phải (TƯƠNG TỰ hơi sang phải - đừng sang quá).
# 6. Hướng lên trên trái (TƯƠNG TỰ hơi lên trên trái - đừng lên trên quá).
# 7. Hướng lên trên phải (TƯƠNG TỰ hơi lên trên phải - đừng lên trên quá).
# 8. Hướng xuống dưới trái (TƯƠNG TỰ hơi xuống dưới trái - đừng xuống dưới quá).
# 9. Hướng xuống dưới phải (TƯƠNG TỰ hơi xuống dưới phải - đừng xuống dưới quá).
# #### Chú ý công cụ có đếm ngược từ 3,2,1 và số ảnh đã chụp. Khi chụp đủ 27 ảnh, công cụ tự tắt
#
# #### Thay MrABC bằng tên của người chụp
# #### Muốn chụp nhiều hơn thì thay 27 bằng số khác

# %%
# %%bash
# python3 capture_webcam_face_images.py -d images/dataset -n MrABC -c 27
# Out:
# [ WARN:0] global /tmp/pip-req-build-947ayiyu/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# Traceback (most recent call last):
#   File "capture_webcam_face_images.py", line 35, in <module>
#     show_frame(frame, str(count_down), f"Picture {i+1} of {args['count']}")
#   File "capture_webcam_face_images.py", line 8, in show_frame
#     width, height = frame.shape[:2]
# AttributeError: 'NoneType' object has no attribute 'shape'
# terminate called without an active exception
# bash: line 1: 174872 Aborted                 (core dumped) python3 capture_webcam_face_images.py -d images/dataset -n MrABC -c 27
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-16-fa77b89be811> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'python3 capture_webcam_face_images.py -d images/dataset -n MrABC -c 27\n')
# ...

# %% [markdown]
# #### Sau khi chụp muốn xem chất lượng ảnh thì chạy 2 dòng lệnh phía dưới
# #### Thay MrABC bằng tên của người chụp.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
diplay_image('images/dataset/MrABC')
# Out:
# [INFO] processing image [MrABC] 1/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F0360B62A50>
# [INFO] processing image [MrABC] 2/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F03624974D0>
# [INFO] processing image [MrABC] 3/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F0362497110>
# [INFO] processing image [MrABC] 4/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F03A45B1B50>
# [INFO] processing image [MrABC] 5/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F0362497550>
# [INFO] processing image [MrABC] 6/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F03624974D0>
# [INFO] processing image [MrABC] 7/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F03A45A6C10>
# [INFO] processing image [MrABC] 8/8
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F0362497410>

# %%
from imutils import paths
import os
from pathlib import Path

def diplay_image(dataset):
    # grab the paths to the input images in our dataset
    imagePaths = list(paths.list_images(dataset))

    # loop over the image paths
    for (i, imagePath) in enumerate(imagePaths):
        # extract the person name from the image path
        name = imagePath.split(os.path.sep)[-2]
        print(f"[INFO] processing image [{name}] {i + 1}/{len(imagePaths)}")
        
        
        # load the input image and convert from BGR to RGB for dlib
        image = cv2.imread(imagePath)
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        display(Image.fromarray(rgb_image))
